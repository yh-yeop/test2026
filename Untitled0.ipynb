# %% [markdown]
# <a href="https://colab.research.google.com/github/yh-yeop/test2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(123)
# Out:
# 123

# %%
print('World')
# Out:
# World

# %%
print(13,45,29,sep=':')
print('13:45:29')
# Out:
# 13:45:29
# 13:45:29

# %%
print('hello','python','World')
# Out:
# hello python World

# %%
print('3','01','1004',sep='.')
# Out:
# 3.01.1004

# %%
a=10

# %%
d=[1,2,3,4,5]
print(d[4],d[3])
# Out:
# 5 4

# %%
s=0
def f(n):
  global s
  k=0
  while k<n:
    k+=1
    s+=k
f(3)
print(s)
# Out:
# 6

# %%
name=input()
# Out:
# yhyeop

# %%
name,age=input().split()
# Out:
# yhyeop 18

# %%
d,m,y=input().split('.')
# Out:
# 25.12.2023

# %%
s=input().split()
print(s[0])
print(s[1])
# Out:
# 미강고 프로그래밍
# 미강고
# 프로그래밍

# %%
d=list(map(int,input().split())) # O
d=input().split() # X
# Out:
# 1 2 3 4
# 1 2 3 4

# %%
d,m,y=input().split('.')
print(y,m,d,sep='.')
# Out:
# 25.12.2023
# 2023.12.25
